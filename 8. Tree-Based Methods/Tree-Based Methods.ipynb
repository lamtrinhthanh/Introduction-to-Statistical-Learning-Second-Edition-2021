# %%
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## 8.1 The Basics of Decision Trees

# %% [markdown]
# ### 8.1.1 Regression Trees

# %%
hitters = pd.read_csv('../datasets/Hitters.csv')

# %%
hitters.head(10)
# Out:
#           Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     -Andy Allanson    293    66      1    30   29     14      1     293
# 1        -Alan Ashby    315    81      7    24   38     39     14    3449
# 2       -Alvin Davis    479   130     18    66   72     76      3    1624
# 3      -Andre Dawson    496   141     20    65   78     37     11    5628
# 4  -Andres Galarraga    321    87     10    39   42     30      2     396
# 5   -Alfredo Griffin    594   169      4    74   51     35     11    4408
# 6         -Al Newman    185    37      1    23    8     21      2     214
# 7   -Argenis Salazar    298    73      0    24   24      7      3     509
# 8     -Andres Thomas    323    81      6    26   32      8      2     341
# 9    -Andre Thornton    401    92     17    49   66     65     13    5206
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# ...

# %%
hitters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  322 non-null    object
#  1   AtBat       322 non-null    int64
#  2   Hits        322 non-null    int64
#  3   HmRun       322 non-null    int64
#  4   Runs        322 non-null    int64
#  5   RBI         322 non-null    int64
#  6   Walks       322 non-null    int64
#  7   Years       322 non-null    int64
#  8   CAtBat      322 non-null    int64
#  9   CHits       322 non-null    int64
#  10  CHmRun      322 non-null    int64
#  11  CRuns       322 non-null    int64
#  12  CRBI        322 non-null    int64
#  13  CWalks      322 non-null    int64
#  14  League      322 non-null    object
#  15  Division    322 non-null    object
#  16  PutOuts     322 non-null    int64
#  17  Assists     322 non-null    int64
#  18  Errors      322 non-null    int64
# ...

# %%
hitters.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean   380.928571  101.024845   10.770186   50.909938   48.027950   38.742236
# std    153.404981   46.454741    8.709037   26.024095   26.166895   21.639327
# min     16.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    255.250000   64.000000    4.000000   30.250000   28.000000   22.000000
# 50%    379.500000   96.000000    8.000000   48.000000   44.000000   35.000000
# 75%    512.000000  137.000000   16.000000   69.000000   64.750000   53.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years       CAtBat        CHits      CHmRun        CRuns  \
# count  322.000000    322.00000   322.000000  322.000000   322.000000
# mean     7.444099   2648.68323   717.571429   69.490683   358.795031
# ...

# %%
display(hitters.isnull().sum(axis=0))
#drop na
hitters.dropna(axis=0, inplace=True)
# Out:
# Unnamed: 0     0
# AtBat          0
# Hits           0
# HmRun          0
# Runs           0
# RBI            0
# Walks          0
# Years          0
# CAtBat         0
# CHits          0
# CHmRun         0
# CRuns          0
# CRBI           0
# CWalks         0
# League         0
# Division       0
# PutOuts        0
# Assists        0
# Errors         0
# Salary        59
# NewLeague      0
# dtype: int64

# %%
counts, bins = np.histogram(hitters['Salary'])

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot(121)
ax1.hist(hitters['Salary'],density=0)
ax1.set(xlabel='Salary', ylabel='Count')
ax2 = plt.subplot(122)
ax2.hist(np.log(hitters['Salary']), density=0)
ax2.set(xlabel='Salary', ylabel='Count');

# %%
X = hitters[['Years', 'Hits']]
y = np.log(hitters['Salary'])

# %%
tree_reg = DecisionTreeRegressor(max_leaf_nodes=3)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=3,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
plt.figure(figsize=(12, 8))
plot_tree(tree_reg, feature_names=X.columns.tolist(), filled=True)

# %%
from sklearn.tree import export_graphviz
import PIL
import io
from IPython.display import Image

# %%
import pydotplus
graph = pydotplus.graph_from_dot_data(export_graphviz(tree_reg, feature_names=X.columns.tolist(), filled=True))
graph.write_png('baseball_tree.png')
# Out:
# True

# %%
PIL.Image.open('baseball_tree.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=357x359 at 0x181E06074A8>

# %%
Image(graph.create_png())

# %%
PIL.Image.open(io.BytesIO(graph.create_png()))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=357x359 at 0x181E0E57710>
